# %% [markdown]
# # Welcome to COVID19 Data Analysis Notebook

# %% [markdown]
# # Let's Import the modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print("Modules are importted.")
# Out:
# Modules are importted.

# %% [markdown]
# # Task 2

# %% [markdown]
# # Task 2.1: importing COVID19 dataset

# %%
corona_dataset_csv = pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")

# %%
# check what is inside the datafram
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
# Check the shape of the dataframe
corona_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# # Task 2.2: Delete the useless columns

# %%
corona_dataset_csv.drop(["Lat","Long"], axis=1, inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# # Task 2.3: Aggregating the rows by the country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()
# Out:
# /tmp/ipykernel_97/3159044292.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# # Task 2.4: Visualizing data related to a country for example China

# %%
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
corona_dataset_aggregated.loc["Spain"].plot()
plt.legend()

# %% [markdown]
# # Task 3: Calculating a good measure
# we need to find a good measure represented as a number, describing the spread of the virus in a country.

# %%
#plot the first 3 days of the spread of the virus in China
corona_dataset_aggregated.loc["China"][:3].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Task 3.1: calculating and plotting the first derivative of the curve

# %%
corona_dataset_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %% [markdown]
# # Task 3.2: Find the Maximum infection rate for China, Italy and Spain

# %%
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc["Italy"].diff().max()
# Out:
# 6557.0

# %%
corona_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 9630.0

# %% [markdown]
# # Task 3.3: Find Maximum infection rate for all of the countries

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for c in countries: 
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated["max_infection_rate"] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# # Task 3.4: Create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rate"])

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %% [markdown]
# # Task 4:
# 1) Importing the WorldHappinessReport.csv dataset
# 2) selecting needed columns for our analysis
# 3) join the datasets
# 4) calculate the correlations as the result of our analysis

# %% [markdown]
# # Task 4.1: Importing the dataset

# %%
happiness_report_csv= pd.read_csv("Datasets/worldwide_happiness_report.csv")

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# # Task4.2: Drop the useless columns

# %%
useless_cols = ["Overall rank", "Score", "Generosity", "Perceptions of corruption"]

# %%
happiness_report_csv.drop(useless_cols,axis=1, inplace=True)
happiness_report_csv.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 happiness_report_csv.drop(useless_cols,axis=1, inplace=True)
#       2 happiness_report_csv.head()
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %% [markdown]
# # Task 4.3: Changing the indices of the dataframe

# %%
happiness_report_csv.set_index("Country or region", inplace=True)

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# # Task 4.4: Join two dataset we have prepared

# %%
# Corona Dataset 
corona_data.shape
# Out:
# (187, 1)

# %%
# world happiness report Dataset

# %%
happiness_report_csv.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(happiness_report_csv, how="inner")
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# # Task 4.5: Correlation matrix

# %%
data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %% [markdown]
# # Task 5: Visualisation of the results
# Our Analysis is not finished unless we visualise the result in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# # Task 5.1: Plotting GDP vs maximum infection rate

# %%
x = data["GDP per capita"]
y = data["max_infection_rate"]
sns.scatterplot(x)
# Out:
# <Axes: ylabel='GDP per capita'>

# %%
sns.scatterplot(np.log(y))
# Out:
# <Axes: ylabel='max_infection_rate'>

# %%
sns.regplot(x,np.log(y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[137], line 1
# ----> 1 sns.regplot(x,np.log(y))
#
# TypeError: regplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# # Task 5.2: Plotting Social support vs maximum infection rate

# %%
x = data["Social support"]
y = data["max_infection_rate"]
sns.scatterplot(x,np.log(y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[142], line 3
#       1 x = data["Social support"]
#       2 y = data["max_infection_rate"]
# ----> 3 sns.scatterplot(x,np.log(y))
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.regplot(x,np.log(y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 sns.regplot(x,np.log(y))
#
# TypeError: regplot() takes from 0 to 1 positional arguments but 2 were given

# %% [markdown]
# # Task 6: Importing COVID19 deaths dataset

# %%
deaths_dataset_csv= pd.read_csv("Datasets/covid19_deaths_dataset.csv")

# %%
deaths_dataset_csv.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# # Task6.2: Drop the useless columns

# %%
deaths_dataset_csv.drop(["Lat","Long"], axis=1, inplace=True)

# %%
deaths_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...       36
# ...

# %% [markdown]
# # Task 6.3: Aggregating the rows by the country

# %%
deaths_dataset_aggregated = deaths_dataset_csv.groupby("Country/Region").sum()
# Out:
# /tmp/ipykernel_97/716098595.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   deaths_dataset_aggregated = deaths_dataset_csv.groupby("Country/Region").sum()

# %%
deaths_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       36       40       42
# Albania               0        0        0  ...       26       27       27
# Algeria               0        0        0  ...      392      402      407
# Andorra               0        0        0  ...       37       37       37
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 101)

# %% [markdown]
# # Task 6.4: Visualizing data related to a country for example China

# %%
deaths_dataset_aggregated.loc["China"].plot()
deaths_dataset_aggregated.loc["Italy"].plot()
deaths_dataset_aggregated.loc["Spain"].plot()
plt.legend()

# %% [markdown]
# # Task 7: Calculating a good measure

# %%
#plot the first 3 days of the death of the virus in China
deaths_dataset_aggregated.loc["China"][:3].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Task 7.1: calculating and plotting the first derivative of the curve

# %%
deaths_dataset_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %% [markdown]
# # Task 7.2: Find the Maximum death rate for China, Italy and Spain

# %%
deaths_dataset_aggregated.loc["China"].diff().max()
# Out:
# 1290.0

# %%
deaths_dataset_aggregated.loc["Italy"].diff().max()
# Out:
# 919.0

# %%
deaths_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 961.0

# %% [markdown]
# # Task 7.3: Find Maximum death rate for all of the countries

# %%
countries = list(deaths_dataset_aggregated.index)
max_death_rates = []
for c in countries: 
    max_death_rates.append(deaths_dataset_aggregated.loc[c].diff().max())
deaths_dataset_aggregated["max_death_rate"] = max_death_rates

# %%
deaths_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       40       42       43
# Albania               0        0        0  ...       27       27       27
# Algeria               0        0        0  ...      402      407      415
# Andorra               0        0        0  ...       37       37       40
# ...

# %% [markdown]
# # Task 7.4: Create a new dataframe with only needed column

# %%
death_data = pd.DataFrame(deaths_dataset_aggregated["max_death_rate"])

# %%
death_data.head()
# Out:
#                 max_death_rate
# Country/Region
# Afghanistan                7.0
# Albania                    4.0
# Algeria                   30.0
# Andorra                    4.0
# Angola                     2.0
